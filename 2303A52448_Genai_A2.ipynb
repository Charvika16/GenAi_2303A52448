# %% [markdown]
# <a href="https://colab.research.google.com/github/Charvika16/GenAi_2303A52448/blob/main/2303A52448_Genai_A2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Consider a chocolate manufacturing company that produces only two types of chocolate i.e. A and B. Both the chocolates require Milk and Choco only. To manufacture each unit of A and B, the following quantities are required: Each unit of A requires 1 unit of Milk and 3 units of Choco Each unit of B requires 1 unit of Milk and 2 units of Choco The company kitchen has a total of 5 units of Milk and 12 units of Choco. On each sale, the company makes a profit of Rs 6 per unit A sold and Rs 5 per unit B sold. Now, the company wishes to maximize its profit. How many units of A and B should it produce respectively?

# %% [markdown]
# ![As2-1.jpg](data:image/jpeg;base64,...)

# %%
from scipy.optimize import linprog
import math as mt
import numpy as np
obj=[-6,-5]
A=[[1,1],[3,2]]
B=[5,12]
boundaries=[(0,float("inf")),(0,float("inf"))]
opt=linprog(c=obj,A_ub=A,b_ub=B,bounds=boundaries)
choc_A=np.round(opt.x[0])
choc_B=np.round(opt.x[1])
bounds=[(0,float('inf')),(0,float('inf'))]
opt=linprog(c=obj,A_ub=A,b_ub=B,bounds=bounds)
choco=np.round(opt.x)
print(f"No.of A={choco[0]} B={choco[1]}")
A_units, B_units = opt.x
print(f"There company can produce ")
print(f"Optimal solution: No. of A = {choco[0]}, No. of B = {choco[1]}")
print(f"Maximum profit: Rs {int(-opt.fun)}")
# Out:
# No.of A=2.0 B=3.0
# There company can produce
# Optimal solution: No. of A = 2.0, No. of B = 3.0
# Maximum profit: Rs 27

# %% [markdown]
# 2. A farmer has recently acquired a 110 hectares piece of land. He has decided to grow Wheat and Barley on that land. Due to the quality of the sun and the region's excellent climate, the entire production of Wheat and Barley can be sold. He wants to know how to plant each variety in the 110 hectares, given the costs, net profits, and labor requirements according to the data shown below:
#
# Crop	Cost (Rs/Hec)	Profit (Price/Hec)	Man-days/Hec
# Wheat	7000	50	10
# Barley	2000	120	30
# The farmer has a budget of Rs. 7,00,000 and availability of 1,200 man-days during the planning horizon. Find the optimal solution and the optimal value.

# %% [markdown]
# ![As2-2.jpg](data:image/jpeg;base64,...)

# %%
obj = [-50,-120]
A=[[7000,2000],[10,30]]
B=[700000,1200]
A_eq=[[1,1]]
B_eq=[100]
bounds=[(0,float('inf')),(0,float('inf'))]

opt=linprog(c = obj, A_ub = A, b_ub = B, A_eq = A_eq, b_eq = B_eq, bounds = bounds , method='simplex')
chac=np.round(opt.x)
print(f"Number of A (Wheat) = {chac[0]}, B (Barley) = {chac[1]}")
max_profit = -opt.fun
print(f"The farmer should plant 'Wheat' on {chac[0]} hectares and 'Barley' on {chac[1]} hectares to get the maximum profit of Rs {max_profit:.2f}.\n\n")
# Out:
# Number of A (Wheat) = 90.0, B (Barley) = 10.0
# The farmer should plant 'Wheat' on 90.0 hectares and 'Barley' on 10.0 hectares to get the maximum profit of Rs 5700.00.
# <ipython-input-3-1d5af404dc6f>:8: DeprecationWarning: `method='simplex'` is deprecated and will be removed in SciPy 1.11.0. Please use one of the HiGHS solvers (e.g. `method='highs'`) in new code.
#   opt=linprog(c = obj, A_ub = A, b_ub = B, A_eq = A_eq, b_eq = B_eq, bounds = bounds , method='simplex')
